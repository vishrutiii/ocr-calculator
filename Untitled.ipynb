# %%
import cv2
import pytesseract
import PIL
import matplotlib.pyplot as plt
import numpy as np

from PIL import Image

pytesseract.pytesseract.tesseract_cmd = 'C:\\Users\\dev24\\AppData\\Local\\Programs\\Tesseract-OCR\\tesseract.exe'

# %%
path = "./Images/WIN_20210924_17_33_05_Pro.jpg"

# %%
img = cv2.imread(path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
ret, thresh = cv2.threshold(img,160, 255, cv2.THRESH_BINARY_INV)
plt.imshow(thresh)

# %%
bitwise_not = cv2.bitwise_not(gray)
plt.imshow(bitwise_not)

# %%
smooth = cv2.GaussianBlur(bitwise_not,(21,21),sigmaX = 0,sigmaY = 0)
plt.imshow(smooth)

# %%
final = cv2.divide(bitwise_not, 255-smooth, scale = 256)
plt.imshow(final)

# %%
print(pytesseract.image_to_string(final))
